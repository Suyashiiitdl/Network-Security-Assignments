# %%
#ENCRYPTION
RCON = [0x01, 0x02, 0x04, 0x08, 0x10, 0x20, 0x40, 0x80, 0x1b, 0x36]

SBOX = [
    ,
]

INV_SBOX = [
    
]
encryptions = []
decryptions = []
def sub_word(word):
    return [SBOX[b] for b in word]

def rot_word(word):
    return word[1:] + word[:1]

def key_expansion(key):
    words = [[] for _ in range(44)]
    for i in range(4):
        words[i] = key[i*4:i*4+4]
    for i in range(4, 44):
        temp = words[i-1]
        if i % 4 == 0:
            temp = sub_word(rot_word(temp))
            temp[0] ^= RCON[i//4 - 1]
        words[i] = [words[i-4][j] ^ temp[j] for j in range(4)]
    return words

def add_round_key(state, round_key):
    rk = []
    for i in range(4):
        rk.extend(round_key[i])
    return [s ^ rk[i] for i, s in enumerate(state)]

def sub_bytes(state):
    return [SBOX[b] for b in state]

def shift_rows(state):
    s = state[:]
    s[1], s[5], s[9],  s[13] = state[5],  state[9],  state[13], state[1]
    s[2], s[6], s[10], s[14] = state[10], state[14], state[2],  state[6]
    s[3], s[7], s[11], s[15] = state[15], state[3],  state[7],  state[11]
    return s

def xtime(a):
    return (((a << 1) ^ 0x1b) & 0xff) if (a & 0x80) else (a << 1)

def mix_columns(state):
    s = []
    for i in range(0, 16, 4):
        t = state[i] ^ state[i+1] ^ state[i+2] ^ state[i+3]
        u = state[i]
        s0 = state[i]   ^ t ^ xtime(state[i]   ^ state[i+1])
        s1 = state[i+1] ^ t ^ xtime(state[i+1] ^ state[i+2])
        s2 = state[i+2] ^ t ^ xtime(state[i+2] ^ state[i+3])
        s3 = state[i+3] ^ t ^ xtime(state[i+3] ^ u)
        s += [s0, s1, s2, s3]
    return s

def encrypt(plaintext, key, rounds=10):
    expanded = key_expansion(key)
    state = plaintext[:]
    state = add_round_key(state, expanded[:4])
    for r in range(1, rounds):
        state = sub_bytes(state)
        state = shift_rows(state)
        state = mix_columns(state)
        state = add_round_key(state, expanded[r*4:r*4+4])
        print(f"Encryption after round {r}: {state}")
        encryptions.append(state)
    state = sub_bytes(state)
    state = shift_rows(state)
    state = add_round_key(state, expanded[rounds*4:rounds*4+4])
    print(f"Encryption after round {rounds}: {state}")
    encryptions.append(state)
    return state

def mul_gf(a, b):
    r = 0
    for _ in range(8):
        if b & 1:
            r ^= a
        hi = a & 0x80
        a <<= 1
        a &= 0xFF
        if hi:
            a ^= 0x1B
        b >>= 1
    return r


#DECRYPTION
def inv_sub_word(word):
    return [INV_SBOX[b] for b in word]

def inv_sub_bytes(state):
    return [INV_SBOX[b] for b in state]

def inv_rot_word(word):
    return word[-1:] + word[:-1]

def inv_shift_rows(state):
    s = state[:]
    s[1],  s[5],  s[9],  s[13] = state[13], state[1],  state[5],  state[9]
    s[2],  s[6],  s[10], s[14] = state[10], state[14], state[2],  state[6]
    s[3],  s[7],  s[11], s[15] = state[7],  state[11], state[15], state[3]
    return s

def inv_mix_columns(state):
    s = []
    for i in range(0, 16, 4):
        a0 = state[i]
        a1 = state[i+1]
        a2 = state[i+2]
        a3 = state[i+3]
        s0 = mul_gf(a0, 0x0e) ^ mul_gf(a1, 0x0b) ^ mul_gf(a2, 0x0d) ^ mul_gf(a3, 0x09)
        s1 = mul_gf(a0, 0x09) ^ mul_gf(a1, 0x0e) ^ mul_gf(a2, 0x0b) ^ mul_gf(a3, 0x0d)
        s2 = mul_gf(a0, 0x0d) ^ mul_gf(a1, 0x09) ^ mul_gf(a2, 0x0e) ^ mul_gf(a3, 0x0b)
        s3 = mul_gf(a0, 0x0b) ^ mul_gf(a1, 0x0d) ^ mul_gf(a2, 0x09) ^ mul_gf(a3, 0x0e)
        s.extend([s0, s1, s2, s3])
    return s



def decrypt(ciphertext, key, rounds=10):
    expanded = key_expansion(key)
    state = ciphertext[:]
    state = add_round_key(state, expanded[rounds*4:rounds*4+4])
    state = inv_shift_rows(state)
    state = inv_sub_bytes(state)
    print(f"Decryption after round {rounds}: {state}")
    decryptions.append(state)
    for r in range(rounds-1, 0, -1):
        state = add_round_key(state, expanded[r*4:r*4+4])
        state = inv_mix_columns(state)
        state = inv_shift_rows(state)
        state = inv_sub_bytes(state)
        if r==1:
            state = add_round_key(state, expanded[:4])
        print(f"Decryption after round {r}: {state}")
        decryptions.append(state)

    return state

sample_key = [
    0x2b, 0x7e, 0x15, 0x16,
    0x28, 0xae, 0xd2, 0xa6,
    0xab, 0xf7, 0x15, 0x88,
    0x09, 0xcf, 0x4f, 0x3c
]

lists = []
with open('inputs.txt', 'r') as file:
    for line in file:
        hex_list = [int(x, 16) for x in line.split()]
        if hex_list:  
            lists.append(hex_list)

sample_plaintext1, sample_plaintext2, sample_plaintext3 = lists


rounds = 10

inputs = [sample_plaintext1, sample_plaintext2, sample_plaintext3]

for i, input in enumerate(inputs):
    output_file = f"output_input:{i+1}.txt"

    with open(output_file, "w") as file:
        file.write("=" * 50 + f" INPUT: {input} " + "=" * 50 + "\n")
        print("=" * 50 + f" INPUT: {input} " + "=" * 50)

        file.write("ENCRYPTION\n\n")
        print("ENCRYPTION\n")

        file.write(f"Plaintext: {[x for x in input]}\n")
        print(f"Plaintext: {[x for x in input]}")

        encrypted = encrypt(input, sample_key, rounds)

        file.write(f"Encrypted: {[x for x in encrypted]}\n")
        print(f"Encrypted: {[x for x in encrypted]}")

        file.write("\nDECRYPTION\n\n")
        print("\nDECRYPTION\n")

        file.write(f"ciphertext: {[x for x in encrypted]}\n")
        print(f"ciphertext: {[x for x in encrypted]}")

        decrypted = decrypt(encrypted, sample_key, rounds)

        file.write(f"Decrypted: {[x for x in decrypted]}\n\n")
        print(f"Decrypted: {[x for x in decrypted]}\n")

        decryptions = [encrypted] + decryptions

        file.write(f"Plaintext: {input} <======> Decrypted: {decrypted}\n\n")
        print(f"Plaintext: {input} <======> Decrypted: {decrypted}\n")

        for i in range(10):
            if encryptions[i] == decryptions[9 - i]:
                file.write(f"Round {i + 1} Encryption: {encryptions[i]} <=====> Round {9 - i} Decryption: {decryptions[9 - i]} <====> Matched\n")
                print(f"Round {i + 1} Encryption: {encryptions[i]} <=====> Round {9 - i} Decryption: {decryptions[9 - i]} <====> Matched")
            else:
                file.write(f"Round {i + 1} Encryption: {encryptions[i]} <=====> Round {9 - i} Decryption: {decryptions[9 - i]} <====> Not Matched\n")
                print(f"Round {i + 1} Encryption: {encryptions[i]} <=====> Round {9 - i} Decryption: {decryptions[9 - i]} <====> Not Matched")

        file.write("\n")
        print("\n")

    encryptions = []
    decryptions = []
# Out:
# ================================================== INPUT: [50, 67, 246, 168, 136, 90, 48, 141, 49, 49, 152, 162, 224, 55, 7, 52] ==================================================
# ENCRYPTION
#
# Plaintext: [50, 67, 246, 168, 136, 90, 48, 141, 49, 49, 152, 162, 224, 55, 7, 52]
# Encryption after round 1: [164, 156, 127, 242, 104, 159, 53, 43, 107, 91, 234, 67, 2, 106, 80, 73]
# Encryption after round 2: [170, 143, 95, 3, 97, 221, 227, 239, 130, 210, 74, 210, 104, 50, 70, 154]
# Encryption after round 3: [72, 108, 78, 238, 103, 29, 157, 13, 77, 227, 177, 56, 214, 95, 88, 231]
# Encryption after round 4: [224, 146, 127, 232, 200, 99, 99, 192, 217, 177, 53, 80, 133, 184, 190, 1]
# Encryption after round 5: [241, 0, 111, 85, 193, 146, 76, 239, 124, 200, 139, 50, 93, 181, 213, 12]
# Encryption after round 6: [38, 14, 46, 23, 61, 65, 183, 125, 232, 100, 114, 169, 253, 210, 139, 37]
# Encryption after round 7: [90, 65, 66, 177, 25, 73, 220, 31, 163, 224, 25, 101, 122, 140, 4, 12]
# ...
